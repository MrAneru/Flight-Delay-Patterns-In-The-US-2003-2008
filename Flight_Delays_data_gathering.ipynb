# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd

# %matplotlib inline

# %%
df_2000 = dd.read_csv('2000.csv.bz2', compression = 'bz2', dtype={'CRSElapsedTime': 'float64'}, blocksize=None)

# %%
df_2000.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2000      1          28          5   1647.0        1647   1906.0
# 1  2000      1          29          6   1648.0        1647   1939.0
# 2  2000      1          30          7      NaN        1647      NaN
# 3  2000      1          31          1   1645.0        1647   1852.0
# 4  2000      1           1          6    842.0         846   1057.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1859            HP        154  ...     15       11          0
# 1        1859            HP        154  ...      5       47          0
# 2        1859            HP        154  ...      0        0          1
# 3        1859            HP        154  ...      7       14          0
# 4        1101            HP        609  ...      3        8          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df_2000.shape
# Out:
# (Delayed('int-4193eebc-f151-46a5-8e71-e6e47edd5f1a'), 29)

# %%
df_2000.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 29 entries, Year to LateAircraftDelay
# dtypes: object(4), float64(13), int64(12)

# %%
df_2000.describe()
# Out:
# Dask DataFrame Structure:
#                   Year    Month DayofMonth DayOfWeek  DepTime CRSDepTime  ArrTime CRSArrTime FlightNum ActualElapsedTime CRSElapsedTime  AirTime ArrDelay DepDelay Distance   TaxiIn  TaxiOut Cancelled CancellationCode Diverted CarrierDelay WeatherDelay NASDelay SecurityDelay LateAircraftDelay
# npartitions=1
#                float64  float64    float64   float64  float64    float64  float64    float64   float64           float64        float64  float64  float64  float64  float64  float64  float64   float64          float64  float64      float64      float64  float64       float64           float64
#                    ...      ...        ...       ...      ...        ...      ...        ...       ...               ...            ...      ...      ...      ...      ...      ...      ...       ...              ...      ...          ...          ...      ...           ...               ...
# Dask Name: describe-numeric, 120 tasks

# %%
df_2000_2008 = dd.read_csv('df_2000_2008.csv', dtype={'CancellationCode': 'object'})

# %%
df_2000_2008.tail(10)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 581541  2008      4          17          4    712.0         720    823.0
# 581542  2008      4          17          4    934.0         940   1036.0
# 581543  2008      4          17          4    739.0         740    951.0
# 581544  2008      4          17          4    601.0         600    823.0
# 581545  2008      4          17          4   1047.0        1050   1248.0
# 581546  2008      4          17          4   1025.0        1025   1234.0
# 581547  2008      4          17          4   1319.0        1320   1527.0
# 581548  2008      4          17          4   1335.0        1335   1556.0
# 581549  2008      4          17          4   1933.0        1935   2140.0
# 581550  2008      4          17          4    621.0         615    752.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 581541         844            DL       1203  ...    8.0     13.0          0
# ...

# %%
df_2000_2008.describe().compute()
# Out:
#                Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  5.466495e+07  5.466495e+07  5.466495e+07  5.466495e+07  5.347104e+07
# mean   2.003921e+03  6.325625e+00  1.572488e+01  3.940372e+00  1.344600e+03
# std    2.392423e+00  3.453531e+00  8.783428e+00  1.990147e+00  4.771615e+02
# min    2.000000e+03  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.002000e+03  4.000000e+00  9.000000e+00  2.000000e+00  9.440000e+02
# 50%    2.004000e+03  6.000000e+00  1.800000e+01  4.000000e+00  1.346000e+03
# 75%    2.006000e+03  1.000000e+01  2.500000e+01  6.000000e+00  1.754000e+03
# max    2.008000e+03  1.200000e+01  3.100000e+01  7.000000e+00  2.930000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  5.466495e+07  5.335730e+07  5.466495e+07  5.466495e+07
# mean   1.337854e+03  1.492052e+03  1.501052e+03  1.854903e+03
# std    4.655009e+02  5.016991e+02  4.825841e+02  1.762446e+03
# ...

# %%
df_2001 = pd.read_csv('2001.csv.bz2', compression = 'bz2', encoding = 'latin-1')

# %%
df_2002 = pd.read_csv('2002.csv.bz2', compression = 'bz2', encoding = 'latin-1')

# %%
df_2003 = pd.read_csv('2003.csv.bz2', compression = 'bz2', low_memory=False)

# %%
df_2004 = pd.read_csv('2004.csv.bz2', compression = 'bz2', low_memory=False)

# %%
df_2005 = pd.read_csv('2005.csv.bz2', compression = 'bz2')

# %%
df_2006 = pd.read_csv('2006.csv.bz2', compression = 'bz2')

# %%
df_2007 = pd.read_csv('2007.csv.bz2', compression = 'bz2')

# %%
df_2007.shape
# Out:
# (7453215, 29)

# %%
df_2008 = pd.read_csv('2008.csv.bz2', compression = 'bz2')

# %%
df_2008.shape
# Out:
# (2389217, 29)

# %%
frames = [df_2000, df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008]

# %%
df_2000_2008 = pd.concat(frames)

# %%
df_2000_2008.shape
# Out:
# (54664946, 29)

# %%
df_2000_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54664946 entries, 0 to 2389216
# Data columns (total 29 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Year               int64
#  1   Month              int64
#  2   DayofMonth         int64
#  3   DayOfWeek          int64
#  4   DepTime            float64
#  5   CRSDepTime         int64
#  6   ArrTime            float64
#  7   CRSArrTime         int64
#  8   UniqueCarrier      object
#  9   FlightNum          int64
#  10  TailNum            object
#  11  ActualElapsedTime  float64
#  12  CRSElapsedTime     float64
#  13  AirTime            float64
#  14  ArrDelay           float64
#  15  DepDelay           float64
#  16  Origin             object
#  17  Dest               object
#  18  Distance           int64
#  19  TaxiIn             float64
#  20  TaxiOut            float64
#  21  Cancelled          int64
#  22  CancellationCode   object
#  23  Diverted           int64
# ...

# %%
df_2000_2008.describe()
# Out:
#                Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  5.466495e+07  5.466495e+07  5.466495e+07  5.466495e+07  5.347104e+07
# mean   2.003921e+03  6.325625e+00  1.572488e+01  3.940372e+00  1.344600e+03
# std    2.392423e+00  3.453531e+00  8.783428e+00  1.990147e+00  4.771615e+02
# min    2.000000e+03  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.002000e+03  3.000000e+00  8.000000e+00  2.000000e+00  9.320000e+02
# 50%    2.004000e+03  6.000000e+00  1.600000e+01  4.000000e+00  1.331000e+03
# 75%    2.006000e+03  9.000000e+00  2.300000e+01  6.000000e+00  1.735000e+03
# max    2.008000e+03  1.200000e+01  3.100000e+01  7.000000e+00  2.930000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  5.466495e+07  5.335730e+07  5.466495e+07  5.466495e+07
# mean   1.337854e+03  1.492052e+03  1.501052e+03  1.854903e+03
# std    4.655009e+02  5.016991e+02  4.825841e+02  1.762446e+03
# ...

# %%
df_2000_2008.sample(50)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4244626  2006      8           2          3    643.0         645    841.0
# 5190291  2000     11          13          1   1729.0        1730   2002.0
# 1562650  2002      4           4          4   1304.0        1310   1727.0
# 6311377  2003     12          25          4      NaN        1015      NaN
# 4676820  2002     11           1          5    831.0         830    849.0
# 4672917  2004      8          26          4   1540.0        1530   1648.0
# 1677962  2002      4          15          1    854.0         900   1113.0
# 3579927  2001      7          14          6   2027.0        2030   2209.0
# 5537745  2005     10          25          2   1542.0        1415   1648.0
# 5144787  2001     11          27          2   1147.0        1140   1435.0
# 5077775  2007      9          25          2   1155.0        1155   1411.0
# 6658302  2007     11          19          1   1430.0        1430   1628.0
# ...

# %%
#df_2000_2008.to_csv('df_2000_2008.csv', index = False)
